# %% [markdown]
# <a href="https://colab.research.google.com/github/marcosranes/Bootcamp_Python_Pro_Colab/blob/main/Pir%C3%A2mides1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def piramide7(num, desloc=True, diamond=False):
    for c in range(1, num + 1):
        for d in range(num + desloc, 0, -1):
            if d > c:
                print(f"{'  ' * diamond}", end='')
            else:
                print(f"{'0' if c < 10 else ''}{c}", end='  ')
        print('')

# %%
def piramide8(num, desloc=True, diamond=False):
#   for c in range(1, num + 1):
    for c in range(num, 0, -1):
        for d in range(num + desloc, 0, -1):
            if d > c:
                print(f"{'  ' * diamond}", end='')
            else:
                print(f"{'0' if c < 10 else ''}{c}", end='  ')
        print('')

# %%
piramide7(10, 17, True), piramide7(17, 10, True)
piramide8(27, False, True)
# Out:
#                                                     01
#                                                   02  02
#                                                 03  03  03
#                                               04  04  04  04
#                                             05  05  05  05  05
#                                           06  06  06  06  06  06
#                                         07  07  07  07  07  07  07
#                                       08  08  08  08  08  08  08  08
#                                     09  09  09  09  09  09  09  09  09
#                                   10  10  10  10  10  10  10  10  10  10
#                                                     01
#                                                   02  02
#                                                 03  03  03
#                                               04  04  04  04
#                                             05  05  05  05  05
# ...

# %%
piramide7(14, True)
piramide7(14, True)
piramide8(15, False)
piramide8(15, False)
# Out:
# 01
# 02  02
# 03  03  03
# 04  04  04  04
# 05  05  05  05  05
# 06  06  06  06  06  06
# 07  07  07  07  07  07  07
# 08  08  08  08  08  08  08  08
# 09  09  09  09  09  09  09  09  09
# 10  10  10  10  10  10  10  10  10  10
# 11  11  11  11  11  11  11  11  11  11  11
# 12  12  12  12  12  12  12  12  12  12  12  12
# 13  13  13  13  13  13  13  13  13  13  13  13  13
# 14  14  14  14  14  14  14  14  14  14  14  14  14  14
# 01
# 02  02
# 03  03  03
# 04  04  04  04
# 05  05  05  05  05
# 06  06  06  06  06  06
# 07  07  07  07  07  07  07
# 08  08  08  08  08  08  08  08
# 09  09  09  09  09  09  09  09  09
# 10  10  10  10  10  10  10  10  10  10
# 11  11  11  11  11  11  11  11  11  11  11
# 12  12  12  12  12  12  12  12  12  12  12  12
# 13  13  13  13  13  13  13  13  13  13  13  13  13
# 14  14  14  14  14  14  14  14  14  14  14  14  14  14
# 15  15  15  15  15  15  15  15  15  15  15  15  15  15  15
# 14  14  14  14  14  14  14  14  14  14  14  14  14  14
# ...

# %%
piramide7(10, 15, True)
piramide7(15, 20, True)
piramide7(20, False, True)
# Out:
#                                                 01
#                                               02  02
#                                             03  03  03
#                                           04  04  04  04
#                                         05  05  05  05  05
#                                       06  06  06  06  06  06
#                                     07  07  07  07  07  07  07
#                                   08  08  08  08  08  08  08  08
#                                 09  09  09  09  09  09  09  09  09
#                               10  10  10  10  10  10  10  10  10  10
#                                                                     01
#                                                                   02  02
#                                                                 03  03  03
#                                                               04  04  04  04
# ...

# %%
piramide7(15, 30, True)
piramide7(20, False, True)
piramide7(10, 40, True)
# Out:
#                                                                                         01
#                                                                                       02  02
#                                                                                     03  03  03
#                                                                                   04  04  04  04
#                                                                                 05  05  05  05  05
#                                                                               06  06  06  06  06  06
#                                                                             07  07  07  07  07  07  07
#                                                                           08  08  08  08  08  08  08  08
#                                                                         09  09  09  09  09  09  09  09  09
# ...

# %%
piramide7(15, 21, True)
piramide8(16, 20, True)
# Out:
#                                                                       01
#                                                                     02  02
#                                                                   03  03  03
#                                                                 04  04  04  04
#                                                               05  05  05  05  05
#                                                             06  06  06  06  06  06
#                                                           07  07  07  07  07  07  07
#                                                         08  08  08  08  08  08  08  08
#                                                       09  09  09  09  09  09  09  09  09
#                                                     10  10  10  10  10  10  10  10  10  10
#                                                   11  11  11  11  11  11  11  11  11  11  11
# ...
